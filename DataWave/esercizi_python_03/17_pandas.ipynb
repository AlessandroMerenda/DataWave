# %% [markdown]
# Scarica il file customers-1000.csv da https://www.datablist.com/learn/csv/download-sample-csv-files

# %% [markdown]
# Caricamento e ispezione
#     1. Carica il file CSV in un DataFrame.
#     2. Visualizza le prime 10 righe.
#     3. Mostra il numero di righe e colonne.
#     4. Elenca i nomi delle colonne.
#     5. Verifica se ci sono valori nulli.

# %%
import pandas as pd

df = pd.read_csv('/Users/alessandromerenda/Downloads/customers-1000.csv')

df.head(10)
df.info()
df.columns
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              1000 non-null   int64
#  1   Customer Id        1000 non-null   object
#  2   First Name         1000 non-null   object
#  3   Last Name          1000 non-null   object
#  4   Company            1000 non-null   object
#  5   City               1000 non-null   object
#  6   Country            1000 non-null   object
#  7   Phone 1            1000 non-null   object
#  8   Phone 2            1000 non-null   object
#  9   Email              1000 non-null   object
#  10  Subscription Date  1000 non-null   object
#  11  Website            1000 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 93.9+ KB
# Index                0
# Customer Id          0
# First Name           0
# Last Name            0
# Company              0
# ...

# %%
df
# Out:
#      Index      Customer Id First Name Last Name                      Company  \
# 0        1  dE014d010c7ab0c     Andrew   Goodman                Stewart-Flynn
# 1        2  2B54172c8b65eC3      Alvin      Lane  Terry, Proctor and Lawrence
# 2        3  d794Dd48988d2ac      Jenna   Harding                 Bailey Group
# 3        4  3b3Aa4aCc68f3Be   Fernando      Ford                 Moss-Maxwell
# 4        5  D60df62ad2ae41E       Kara     Woods              Mccarthy-Kelley
# ..     ...              ...        ...       ...                          ...
# 995    996  FbcCaF483aFaFAE      Diana    Monroe                  Bass-Wilson
# 996    997  979c4D58Ae9a9cc      Jerry   Morales                   Pratt-King
# 997    998  D0DcF6a4BcefCc8     Tracie     Floyd     Holt, Wilson and Shields
# 998    999  90EE9CbbDa374E9       Paul    Barnes     Brown, Oliver and Haynes
# 999   1000  51732B5b2328015    Dominic     Duran                   Durham LLC
#
# ...

# %% [markdown]
# Filtraggio e selezione
#     6. Seleziona tutti i clienti dal paese "Germany".
#     7. Filtra i clienti con email che terminano in .org.
#     8. Trova i clienti iscritti dopo il 2023-01-01.
#     9. Seleziona solo le colonne First Name, Last Name, Email.
#     10. Trova i clienti con Phone 1 che inizia con +1.

# %%
german = df[df['Country'] == 'Germany']

org = df[df['Email'].str.endswith('.org')]

iscrizione = df[df['Subscription Date'] > '2023-01-01']

subdf= df[['First Name', 'Last Name', 'Email']]

phone = df[df['Phone 1'] .str.startswith('+1')]

phone
# Out:
#      Index      Customer Id First Name Last Name                    Company  \
# 4        5  D60df62ad2ae41E       Kara     Woods            Mccarthy-Kelley
# 6        7  73B22Ac8A43DD1A      Julie    Cooley       Yu, Norman and Sharp
# 23      24  c5CB6C5bFB91fdC     Darius   Benitez                  Giles LLC
# 25      26  3d7bE19696ea8Ff    Douglas  Galloway                  Duffy Inc
# 26      27  A093aA90fa014FE    Phyllis    Becker             Oneal and Sons
# ..     ...              ...        ...       ...                        ...
# 965    966  511aEB7e064eBe7      Erika   Collier  Boyd, Sweeney and Gilmore
# 981    982  1dFa2Ae2BA1c6b7     Dakota     Salas               Greene Group
# 995    996  FbcCaF483aFaFAE      Diana    Monroe                Bass-Wilson
# 998    999  90EE9CbbDa374E9       Paul    Barnes   Brown, Oliver and Haynes
# 999   1000  51732B5b2328015    Dominic     Duran                 Durham LLC
#
# ...

# %% [markdown]
# Pulizia dati
#     11. Rimuovi gli spazi iniziali/finali da tutte le stringhe.
#     12. Rendi tutti gli indirizzi email minuscoli.
#     13. Sostituisci i valori nulli in Phone 2 con "Non disponibile".
#     14. Elimina le righe duplicate (se presenti).
#     15. Rimuovi i simboli speciali dalle colonne Company.

# %% [markdown]
# Operazioni su colonne
#     16. Crea una colonna Full Name unendo nome e cognome.
#     17. Estrai il dominio email in una nuova colonna.
#     18. Calcola la lunghezza del nome completo.
#     19. Crea una colonna Is Gmail che vale True se l’email contiene gmail.
#     20. Crea una colonna Anno Iscrizione da Subscription Date.

# %% [markdown]
# Raggruppamenti e aggregazioni
#     21. Conta quanti clienti ci sono per ogni paese.
#     22. Trova il numero medio di caratteri nei nomi per paese.
#     23. Conta quanti clienti hanno un numero di telefono secondario (Phone 2) per città.
#     24. Raggruppa per Country e conta le aziende uniche.
#     25. Trova il paese con più clienti.

# %% [markdown]
# Ordinamenti e ranking
#     26. Ordina i clienti per Subscription Date decrescente.
#     27. Ordina per lunghezza del nome completo.
#     28. Trova i 10 clienti più recenti.
#     29. Trova i 5 paesi con più clienti.
#     30. Aggiungi una colonna Rank per data di iscrizione.

# %% [markdown]
# Analisi avanzata
#     31. Verifica se ci sono email duplicate.
#     32. Trova i clienti con lo stesso First Name e Last Name.
#     33. Conta quanti clienti hanno nomi palindromi.
#     34. Trova i clienti con cognome che inizia e finisce con la stessa lettera.
#     35. Crea una colonna Has Website che vale True se il campo Website non è vuoto.

# %% [markdown]
# Stringhe e regex
#     36. Estrai il TLD (es. .com, .org) dalle email.
#     37. Trova i clienti con Company che contiene "Group".
#     38. Sostituisci "Ltd" con "Limited" nella colonna Company.
#     39. Verifica se Phone 1 è in formato internazionale (+ all’inizio).
#     40. Crea una colonna Initials con le iniziali del nome e cognome.

# %% [markdown]
# Esportazione e salvataggio
#     46. Salva solo i clienti italiani in un nuovo CSV.
#     47. Esporta il DataFrame in formato Excel.
#     48. Salva solo le colonne Full Name, Email, Country in JSON.
#     49. Esporta i clienti iscritti nel 2024 in un file Parquet.
#     50. Crea un file CSV con solo i clienti che hanno entrambi i numeri di telefono.
